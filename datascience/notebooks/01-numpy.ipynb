# %% [markdown]
# # Numpy

# %%
import numpy as np

# %% [markdown]
# # list, tuple, dict, set
#
# =======================
#
# # numpy array

# %%
x = [2,3,4,5]
y = [10,24,5,6]

# %%
arry1 = np.array([2,3,4,5])
arry2 = np.array([10,24,5,6])

# %%
arry1*arry2
# Out:
# array([20, 72, 20, 30])

# %%
arry1.mean()
# Out:
# np.float64(3.5)

# %%
arry1=np.array([21,4,45,3,12,45,4,23,45,34])

# %%
arry1.dtype
# Out:
# dtype('int64')

# %%
arry1.ndim
# Out:
# 1

# %%
arr1=([21,23,45,23,456,56,34,56,1.2,4.6])

# %%
arry1
# Out:
# [21, 23, 45, 23, 456, 56, 34, 56, 1.2, 4.6]

# %%
arr1=([21,23,45,23,456,56,34,56,1.2,4.6,'vishal'])
arr1
# Out:
# [21, 23, 45, 23, 456, 56, 34, 56, 1.2, 4.6, 'vishal']

# %%
arr1=np.array([21,4,45,3,12,45,4,23,45,34])

# %%
arr1[2]
# Out:
# np.int64(45)

# %%
arr1[-1]
# Out:
# np.int64(34)

# %% [markdown]
# # Slicing
# arr1_name[start:end:step] | end-1, step +1

# %%
arr1=([21,23,45,23,456,56,34,56,1.2,4.6])

# %%
# arr1[1:5]
arr1[:5]
# Out:
# [21, 23, 45, 23, 456]
